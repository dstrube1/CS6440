# %% [markdown]
# # NCHS Data Import
# The function **nchsDataImport()** imports the NCHS data. It starts off verifying that the Python library **tika** can be imported; if it cannot be imported, it tries to install it; if the install fails, the function exits, returning an empty string.
#
# Next, this function uses the **parser** submodule of **tika** to read the NCHS data, specifically the **parser.from_file()** function. (Thankfully, the **from_file()** function accepts both local file paths and URLs.)
#
# Finally, the **nchsDataImport()** function returns the content from the data that is read.

# %%
fileName = "https://www.cdc.gov/nchs/data/dvs/LCWK2_2013.pdf"

def nchsDataImport():
    #Purpose: import NCHS data, return content
    try:
        import tika
        #https://pypi.org/project/tika/
    except:
        print("Couldn't import tika")    
        import sys
        # !{sys.executable} -m pip install tika
        try:
            import tika
            print("Now it imports")
        except:
            print("Still doesn't import :(")
            return ""
    #print("Version of tika: " + tika.__version__)
    from tika import parser 
    parsed = parser.from_file(fileName)
    myContent = parsed['content']
    #metadata = parsed['metadata']
    #print("Length of content:")
    #print(len(myContent))
    #print("metadata: ")
    #print(metadata)
    print("Data imported")
    return myContent

content = nchsDataImport()
#print(len(content))
# Out:
# 2021-02-21 23:26:47,289 [MainThread  ] [INFO ]  Retrieving https://www.cdc.gov/nchs/data/dvs/LCWK2_2013.pdf to /var/folders/15/5vtt9tpn6c98kpsc0frpxz140000gn/T/nchs-data-dvs-lcwk2_2013.pdf.
# Data imported

# %% [markdown]
# # Data Cleansing
# The function **setIgnorableLines()** initializes a set of lines that can be ignored while parsing through the NCHS data.
#
# The function **dataCleansing1()** uses the file content returned from **nchsDataImport()**. It parses through the content, skipping over lines that are found in the set **ignorableLines** (initialized in **setIgnorableLines()**) and returning a list of relevant lines.
#
# The function **dataCleansing2()** uses the list returned from **dataCleansing1()**. For each line in this input, a DataRow object is created (unless there are two lines representing the data for a single **DataRow**), using the function **dataRowFromLine()**. The function **dataCleansing2()** returns a list of **DataRow**s

# %%
ignorableLines = set()

def setIgnorableLines():
    #Purpose: Initialize set of ignorableLines
    ignorableLines.add("LCWK2. Deaths, percent of total deaths, and death rates for the 15 leading causes of death in 10-year age groups, by race and sex:")
    ignorableLines.add("12/31/2014 Page")
    ignorableLines.add("Tenth Revision ), race, sex, and age Number")
    ignorableLines.add("Percent of ")
    ignorableLines.add("total deaths Rate")
    ignorableLines.add("Cause of death (based on the International Classification of Diseases,")
    ignorableLines.add("Rank")
    ignorableLines.add("[Rates per 100,000 population in specified group. Rates for")
    ignorableLines.add("not distributed among age groups. Data for races other than white and black should be interpreted with caution because of inconsistencies between the reporting of race")
    ignorableLines.add("on death certificates and on censuses and surveys]")
    ignorableLines.add("United States, 2013")
    ignorableLines.add("... Category not applicable")
    ignorableLines.add("*   Figure does not meet standards of reliability or precision")
    ignorableLines.add("SOURCE: CDC/NCHS, National Vital Statistics System, Mortality 2013")

def dataCleansing1(content):
    #Purpose: take in content from NCHS import, return list of relevant lines
    myList = list()
    if content is None or len(content) == 0:
        print("Content is None or empty")
        return myList
    lines = content.split('\n')
    #print("lines: ")
    #print(len(lines))
    count = 0
    for line in lines:
        if len(line) > 2:
            ignorable = False
            for ignorableLine in ignorableLines:
                if line.startswith(ignorableLine):
                    ignorable = True
            if not ignorable : 
                if count < 100:
                    #print(line)
                    count += 1
                myList.append(line)
    print("Data cleansed, part 1.")
    return myList

setIgnorableLines()
#print(len(content))
dataList1 = dataCleansing1(content)

class DataRow():
    def __init__(self, category, rank, cause, number, percent, rate):
        self.category = category
        self.rank = rank
        self.cause = cause
        self.number = number
        self.percent = percent
        self.rate = rate

def dataRowFromLine(category, rankCause, rest):
    #Purpose: Take in category, rankCause, and the rest of a line, return a DataRow
    rank = rankCause.split(" ")[0]
    firstSpace = rankCause.index(" ")
    cause = rankCause[firstSpace + 1:]
    number = rest.split(" ")[0]
    percent = rest.split(" ")[1]
    rate = rest.split(" ")[2]
    dataRow = DataRow(category, rank, cause, number, percent, rate)
    return dataRow

def dataCleansing2(dataList):
    #Purpose: take in list of relevant lines, return list of DataRows
    allCauses = "... All causes"
    allOther = "... All other causes (Residual)"
    lastIndexOfCloseParen = 0
    isCategoryLine = True
    myList = list()
    count = 0
    category = ""
    for line in dataList:
        if isCategoryLine:
            isCategoryLine = False
            category = line
        else:
            try:
                lastIndexOfCloseParen = line.rindex(")")
            except:
                lastIndexOfCloseParen = -1
            if allCauses in line:
                rankCause = line[0:len(allCauses) + 1]
                
                rest = line[len(allCauses) + 1:]
                dataRow = dataRowFromLine(category, rankCause, rest)
                myList.append(dataRow)
                #print("cause: " + cause)
                #print("rest: " + rest)
                #count += 1
                #if count > 20:
                #    break
            elif allOther in line:
                #get all other data
                rankCause = line[0:len(allOther) + 1]
                rest = line[len(allOther) + 1:]
                dataRow = dataRowFromLine(category, rankCause, rest)
                myList.append(dataRow)
                #print("cause: " + cause)
                #print("rest: " + rest)
                #count += 1
                #if count > 20:
                #    break
                #set flag for next line
                isCategoryLine = True
            else:
                if line[0:1].isnumeric():
                    prevLine = line
                    if lastIndexOfCloseParen == -1:
                        continue
                    rankCause = line[0:lastIndexOfCloseParen + 1]
                    rest = line[lastIndexOfCloseParen + 2:]
                    dataRow = dataRowFromLine(category, rankCause, rest)
                    myList.append(dataRow)
                    #print("cause: " + cause)
                    #print("rest: " + rest)
                    #count += 1
                    #if count > 20:
                    #    break
                else:
                    #print("Doesn't start numeric: " + line)
                    #print("Combining with " + prevLine)
                    try:
                        lastIndexOfCloseParenInPrevLine = prevLine.rindex(")")
                        print("prevLine has unexpected close paren: " + prevLine)
                    except:
                        pass
                    newLine = prevLine + line
                    try:
                        lastIndexOfCloseParen = newLine.rindex(")")
                    except:
                        print("Error encountered while trying to parse combined line: " + newLine)
                    rankCause = newLine[0:lastIndexOfCloseParen + 1]
                    rest = newLine[lastIndexOfCloseParen + 2:]
                    dataRow = dataRowFromLine(category, rankCause, rest)
                    myList.append(dataRow)
                    #print("cause: " + cause)
                    #print("rest: " + rest)
                    #count += 1
                    #if count > 20:
                    #    break
                #print("lastIndexOfCloseParen: " + str(lastIndexOfCloseParen))
    print("Data cleansed, part 2.")
    return myList

dataList2 = dataCleansing2(dataList1)
"""
#Verify dataList2 is good:
#dataList2.reverse()
count = 0
for item in dataList2:
    print(item.category + " - " + item.rank + " - " + item.cause)
    #print(item.number + " - " + item.percent + " - " + item.rate)
    count += 1
    if count > 20:
        break
"""
print("Done")
# Out:
# Data cleansed, part 1.
# Data cleansed, part 2.
# Done

# %% [markdown]
# # Data Analysis
#
# A new class called **ExtendedDataRow** holds all the fields as **DataRow**, plus **average** and **median**.
#
# The function **analysis1()** performs the same statistical operations I did in Exercise 1, but in code. First it initializes a set **categories**; then for each category, finds all items in **dataList2** (the result from **dataCleansing2()**) that are in that category, putting them into a temporary list called **itemsInCategory**. Then for each item in **itemsInCategory**, it sums the **Numbers** to find the **average** while looking for the **median**. (If the number of items in **itemsInCategory** is odd, it's simply a matter of finding the item in the middle of the presorted list; if the number of items in **itemsInCategory** is even, then **median** is found by taking the average of the middle two items.) The medians and averages found for all categories in Exercise 1 matched those found here, in addition to all the other categories found here which included the rest of the data source.
#
# The function **analysis1()** returns its results into a list of **ExtendedDataRow** items called **extendedDataList**.
#
# Interesting digression: While debugging **analysis1()**, I attempted to confirm that each list of items in each category had a size of 17 (one **"All causes"**, one **"All other causes (Residual)"**, and 15 ranked causes). I was suprised to find that some categories had fewer, some had more. This is because some categories had ties for some ranks, and some ranks had a **Number** value of 1.

# %%
class ExtendedDataRow(DataRow):
    def __init__(self, category, rank, cause, number, percent, rate, average, median):
        self.category = category
        self.rank = rank
        self.cause = cause
        self.number = number
        self.percent = percent
        self.rate = rate
        self.average = average
        self.median = median

categories = set()

allCauses = "All causes"
allOther = "All other causes (Residual)"

def analysis1():
    #Purpose: Perform analysis on dataList2 from previous step, return a new data list with average and median
    myList = list()
    for item in dataList2:
        categories.add(item.category)
    #print("Number of categories: " + str(len(categories)))
    for cat in sorted(categories):
        
        itemsInCategory = list()
        for item in dataList2:
            if item.category == cat:
                itemsInCategory.append(item)
                
        #Sum of Numbers for all items in category to find the average 
        #(excluding "All causes" and "All other causes (Residual)")
        sum = 0
        
        #Median is easy to find if the number of items in category is odd
        median = 0
        index = 0
        #If the number of items in category is even, must take the average of the two middle items
        medianSum = 0
        isEven = (len(itemsInCategory) % 2 == 0)
        medianSumIndex = len(itemsInCategory) / 2
        for item in itemsInCategory:
            if (allCauses not in item.cause) and (allOther not in item.cause):
                sum += int(item.number.replace(',',''))
                if isEven and (index == medianSumIndex or index == medianSumIndex - 1):
                    medianSum += int(item.number.replace(',',''))
                elif not isEven and (index == (len(itemsInCategory) - 1) / 2):
                    median = int(item.number.replace(',',''))
            index += 1
        average = sum / (len(itemsInCategory) - 2) # -2 for allCauses & allOther
        if isEven:
            median = medianSum / 2
        print("average for category " + cat + ": " + str(round(average, 1)))
        print("median for category " + cat + ": " + str(median))
        for item in itemsInCategory:            
            extendedDataRow = ExtendedDataRow(item.category, item.rank, item.cause, item.number, item.percent, item.rate, average, median)
            myList.append(extendedDataRow)
        
        #Interesting digression: Not all categories have 17 items:
        if len(itemsInCategory) != 17:
            print("====================================================")
            print(cat + " has " + str(len(itemsInCategory)) + " items")
            for item in itemsInCategory:
                print(item.rank + " - " + item.cause + " - " + item.number)
            print("====================================================")

    print()
    print("Analysis complete.")
    return myList

extendedDataList = analysis1()
# Out:
# average for category All races, both sexes, 1-4 years: 203.1
# median for category All races, both sexes, 1-4 years: 53
# average for category All races, both sexes, 15-24 years: 1662.7
# median for category All races, both sexes, 15-24 years: 193
# average for category All races, both sexes, 25-34 years: 2561.7
# median for category All races, both sexes, 25-34 years: 631
# average for category All races, both sexes, 35-44 years: 3832.7
# median for category All races, both sexes, 35-44 years: 1687
# average for category All races, both sexes, 45-54 years: 9970.1
# median for category All races, both sexes, 45-54 years: 4619
# average for category All races, both sexes, 5-14 years: 279.5
# median for category All races, both sexes, 5-14 years: 128
# average for category All races, both sexes, 55-64 years: 19191.2
# median for category All races, both sexes, 55-64 years: 7135
# average for category All races, both sexes, 65-74 years: 25733.3
# median for category All races, both sexes, 65-74 years: 7693
# average for category All races, both sexes, 75-84 years: 34124.7
# median for category All races, both sexes, 75-84 years: 13949
# average for category All races, both sexes, 85 years and over: 41961.1
# median for category All races, both sexes, 85 years and over: 17239
# average for category All races, both sexes, all ages: 137295.9
# median for category All races, both sexes, all ages: 56979
# average for category All races, female, 1-4 years: 86.0
# median for category All races, female, 1-4 years: 26
# average for category All races, female, 15-24 years: 421.0
# median for category All races, female, 15-24 years: 83
# average for category All races, female, 25-34 years: 744.5
# median for category All races, female, 25-34 years: 241
# average for category All races, female, 35-44 years: 1425.3
# median for category All races, female, 35-44 years: 556
# average for category All races, female, 45-54 years: 3849.6
# median for category All races, female, 45-54 years: 2228
# average for category All races, female, 5-14 years: 116.3
# median for category All races, female, 5-14 years: 55
# average for category All races, female, 55-64 years: 7373.3
# median for category All races, female, 55-64 years: 2453
# average for category All races, female, 65-74 years: 10977.6
# median for category All races, female, 65-74 years: 3691
# average for category All races, female, 75-84 years: 16546.1
# median for category All races, female, 75-84 years: 6609
# average for category All races, female, 85 years and over: 25741.5
# median for category All races, female, 85 years and over: 10174
# average for category All races, female, all ages: 66445.7
# median for category All races, female, all ages: 30175
# average for category All races, male, 1-4 years: 117.1
# median for category All races, male, 1-4 years: 32
# average for category All races, male, 15-24 years: 1246.9
# median for category All races, male, 15-24 years: 114
# average for category All races, male, 25-34 years: 1826.7
# median for category All races, male, 25-34 years: 403
# average for category All races, male, 35-44 years: 2417.8
# median for category All races, male, 35-44 years: 938
# average for category All races, male, 45-54 years: 6120.5
# median for category All races, male, 45-54 years: 2142
# average for category All races, male, 5-14 years: 163.4
# median for category All races, male, 5-14 years: 70
# average for category All races, male, 55-64 years: 11826.6
# median for category All races, male, 55-64 years: 5373
# average for category All races, male, 65-74 years: 14766.5
# median for category All races, male, 65-74 years: 4469
# average for category All races, male, 75-84 years: 17578.6
# median for category All races, male, 75-84 years: 7097
nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 46
# 11 - Septicemia (A40-A41) - 39
# 12 - Parkinson's disease (G20-G21) - 29
# 13 - Pneumonitis due to solids and liquids (J69) - 25
# 14 - Nutritional deficiencies (E40-E64) - 12
# 15 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 9
# 15 - Atherosclerosis (I70) - 9
# ... - All other causes (Residual)  - 512
# ====================================================
# average for category American Indian, both sexes, all ages: 907.8
# median for category American Indian, both sexes, all ages: 521
# average for category American Indian, female, 1-4 years: 5.3
# median for category American Indian, female, 1-4 years: 3.0
# ====================================================
# American Indian, female, 1-4 years has 8 items
# ... - All causes  - 39
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 19
# 2 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 5
# 3 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 4
# 4 - Influenza and pneumonia (J09-J18) - 2
# 5 - Malignant neoplasms (C00-C97) - 1
# 5 - Acute bronchitis and bronchiolitis (J20-J21) - 1
# ... - All other causes (Residual)  - 7
# ====================================================
# average for category American Indian, female, 15-24 years: 11.7
# median for category American Indian, female, 15-24 years: 2.0
# ====================================================
# American Indian, female, 15-24 years has 14 items
# ... - All causes  - 160
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 73
# 2 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 35
# 3 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 12
# 4 - Malignant neoplasms (C00-C97) - 6
# 5 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 5
# 6 - Pregnancy, childbirth and the puerperium (O00-O99) - 3
# 7 - Septicemia (A40-A41) - 1
# 7 - Diabetes mellitus (E10-E14) - 1
# 7 - Influenza and pneumonia (J09-J18) - 1
# 7 - Chronic lower respiratory diseases (J40-J47) - 1
# 7 - Chronic liver disease and cirrhosis (K70,K73-K74) - 1
# 7 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 1
# ... - All other causes (Residual)  - 20
# ====================================================
# average for category American Indian, female, 25-34 years: 17.1
# median for category American Indian, female, 25-34 years: 7
# average for category American Indian, female, 35-44 years: 24.9
# median for category American Indian, female, 35-44 years: 12.0
# ====================================================
# American Indian, female, 35-44 years has 18 items
# ... - All causes  - 496
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 114
# 2 - Chronic liver disease and cirrhosis (K70,K73-K74) - 74
# 3 - Malignant neoplasms (C00-C97) - 54
# 4 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 45
# 5 - Diabetes mellitus (E10-E14) - 20
# 6 - Influenza and pneumonia (J09-J18) - 19
# 6 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 19
# 8 - Cerebrovascular diseases (I60-I69) - 14
# 9 - Septicemia (A40-A41) - 10
# 9 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 10
# 11 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N
nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 34
# 9 - Influenza and pneumonia (J09-J18) - 23
# 10 - Septicemia (A40-A41) - 22
# 11 - Viral hepatitis (B15-B19) - 20
# 12 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 15
# 13 - Essential hypertension and hypertensive renal disease (I10,I12,I15) - 10
# 14 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 6
# 15 - Infections of kidney (N10-N12,N13.6,N15.1) - 4
# 15 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 4
# ... - All other causes (Residual)  - 225
# ====================================================
# average for category American Indian, female, 65-74 years: 76.9
# median for category American Indian, female, 65-74 years: 31
# average for category American Indian, female, 75-84 years: 80.8
# median for category American Indian, female, 75-84 years: 40
# average for category American Indian, female, 85 years and over: 70.5
# median for category American Indian, female, 85 years and over: 38
# average for category American Indian, female, all ages: 400.8
# median for category American Indian, female, all ages: 185
# average for category American Indian, male, 1-4 years: 5.1
# median for category American Indian, male, 1-4 years: 1.5
# ====================================================
# American Indian, male, 1-4 years has 12 items
# ... - All causes  - 65
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 24
# 2 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 11
# 3 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 7
# 4 - Malignant neoplasms (C00-C97) - 2
# 4 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 2
# 6 - Nutritional deficiencies (E40-E64) - 1
# 6 - Cerebrovascular diseases (I60-I69) - 1
# 6 - Influenza and pneumonia (J09-J18) - 1
# 6 - Chronic lower respiratory diseases (J40-J47) - 1
# 6 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 1
# ... - All other causes (Residual)  - 14
# ====================================================
# average for category American Indian, male, 15-24 years: 23.7
# median for category American Indian, male, 15-24 years: 3
# average for category American Indian, male, 25-34 years: 26.5
# median for category American Indian, male, 25-34 years: 3.0
# ====================================================
# American Indian, male, 25-34 years has 22 items
# ... - All causes  - 615
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 241
# 2 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 105
# 3 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 61
# 4 - Chronic liver disease and cirrhosis (K70,K73-K74) - 39
# 5 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 28
# 6 - Malignant neoplasms (C00-C97) - 22
# 7 - Diabetes mellitus (E10-E14) - 7
# 7 - Influenza and pneumonia (J09-J18) - 7
# 9 - Septicemia (A40-A41) - 3
# 9 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 3
# 9 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 3
# 12 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 2
# 12 - Cerebrovascular diseases (I60-I69) - 2
# 14 - Tuberculosis (A16-A19) - 1
# 14 - Human immunodeficiency virus (HIV) disease (B20-B24) - 1
# 14 - Essential hypertension and hypertensive renal disease (I10,I12,I15) - 1
# 14 - Hernia (K40-K46) - 1
# 14 - Legal intervention (Y35,Y89.0) - 1
# 14 - Complications of medical and surgical care (Y40-Y84,Y88) - 1
# 14 - Enterocolitis due to Clostridium difficile  (A04.7) - 1
# ... - All other causes (Residual)  - 85
# ====================================================
# average for category American Indian, male, 35-44 years: 40.8
# median for category American Indian, male, 35-44 years: 10
# average for category American Indian, male, 45-54 years: 77.9
# median for category American Indian, male, 45-54 years: 25
# average for category American Indian, male, 5-14 years: 4.7
# median for category American Indian, male, 5-14 years: 2
# ====================================================
# American Indian, male, 5-14 years has 11 items
# ... - All causes  - 47
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 18
# 2 - Malignant neoplasms (C00-C97) - 8
# 3 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 7
# 4 - Chronic lower respiratory diseases (J40-J47) - 2
# 4 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 2
# 4 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 2
# 7 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 1
# 7 - Pneumonitis due to solids and liquids (J69) - 1
# 7 - Certain conditions originating in the perinatal period (P00-P96) - 1
# ... - All other causes (Residual)  - 5
# ====================================================
# average for category American Indian, male, 55-64 years: 102.9
# median for category American Indian, male, 55-64 years: 34
# average for category American Indian, male, 65-74 years: 93.6
# median for category American Indian, male, 65-74 years: 38.0
# ====================================================
# American Indian, male, 65-74 years has 18 items
# ... - All causes  - 1,758
# 1 - Malignant neoplasms (C00-C97) - 455
# 2 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 443
# 3 - Chronic lower respiratory diseases (J40-J47) - 120
# 4 - Diabetes mellitus (E10-E14) - 118
# 5 - Cerebrovascular diseases (I60-I69) - 69
# 6 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 63
# 7 - Chronic liver disease and cirrhosis (K70,K73-K74) - 55
# 8 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 42
# 9 - Influenza and pneumonia (J09-J18) - 34
# 10 - Septicemia (A40-A41) - 31
# 11 - Essential hypertension and hypertensive renal disease (I10,I12,I15) - 18
# 12 - Viral hepatitis (B15-B19) - 11
# 12 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 11
# 14 - Parkinson's disease (G20-G21) - 9
# 14 - Alzheimer's disease (G30) - 9
# 14 - Aortic aneurysm and dissection (I71) - 9
# ... - All other causes (Residual)  - 261
# ====================================================
# average for category American Indian, male, 75-84 years: 82.5
# median for category American Indian, male, 75-84 years: 35
# average for category American Indian, male, 85 years and over: 45.7
# median for category American Indian, male, 85 years and over: 28
# average for category American Indian, male, all ages: 480.1
# median for category American Indian, male, all ages: 221.5
# ====================================================
# American Indian, male, all ages has 18 items
# ... - All causes  - 9,331
# 1 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 1,843
# 2 - Malignant neoplasms (C00-C97) - 1,650
# 3 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 1,177
# 4 - Chronic liver disease and cirrhosis (K70,K73-K74) - 511
# 5 - Diabetes mellitus (E10-E14) - 490
# 6 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 401
# 7 - Chronic lower respiratory diseases (J40-J47) - 370
# 8 - Cerebrovascular diseases (I60-I69) - 253
# 9 - Influenza and pneumonia (J09-J18) - 190
# 10 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 187
# 11 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N
# 3 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 8
# 4 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 7
# 4 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 7
# 6 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 6
# 7 - Influenza and pneumonia (J09-J18) - 3
# 8 - Chronic lower respiratory diseases (J40-J47) - 2
# 8 - Complications of medical and surgical care (Y40-Y84,Y88) - 2
# 10 - Septicemia (A40-A41) - 1
# 10 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 1
# 10 - Cerebrovascular diseases (I60-I69) - 1
# 10 - Certain conditions originating in the perinatal period (P00-P96) - 1
# ... - All other causes (Residual)  - 29
# ====================================================
# average for category Asian or Pacific Islander, female, 55-64 years: 179.9
# median for category Asian or Pacific Islander, female, 55-64 years: 47
# average for category Asian or Pacific Islander, female, 65-74 years: 249.9
# median for category Asian or Pacific Islander, female, 65-74 years: 90
# average for category Asian or Pacific Islander, female, 75-84 years: 402.9
# median for category Asian or Pacific Islander, female, 75-84 years: 168
# average for category Asian or Pacific Islander, female, 85 years and over: 542.0
# median for category Asian or Pacific Islander, female, 85 years and over: 286
# average for category Asian or Pacific Islander, female, all ages: 1541.2
# median for category Asian or Pacific Islander, female, all ages: 731
# average for category Asian or Pacific Islander, male, 1-4 years: 5.1
# median for category Asian or Pacific Islander, male, 1-4 years: 3
# ====================================================
# Asian or Pacific Islander, male, 1-4 years has 15 items
# ... - All causes  - 96
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 26
# 2 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 13
# 3 - Malignant neoplasms (C00-C97) - 6
# 4 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 5
# 5 - Septicemia (A40-A41) - 3
# 5 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 3
# 5 - Chronic lower respiratory diseases (J40-J47) - 3
# 8 - Meningitis (G00,G03) - 2
# 9 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 1
# 9 - Anemias (D50-D64) - 1
# 9 - Hernia (K40-K46) - 1
# 9 - Infections of kidney (N10-N12,N13.6,N15.1) - 1
# 9 - Certain conditions originating in the perinatal period (P00-P96) - 1
# ... - All other causes (Residual)  - 30
# ====================================================
# average for category Asian or Pacific Islander, male, 15-24 years: 27.7
# median for category Asian or Pacific Islander, male, 15-24 years: 3.0
# ====================================================
# Asian or Pacific Islander, male, 15-24 years has 20 items
# ... - All causes  - 555
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 178
# 2 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 156
# 3 - Malignant neoplasms (C00-C97) - 57
# 4 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 46
# 5 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 27
# 6 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 10
# 7 - Influenza and pneumonia (J09-J18) - 4
# 8 - Septicemia (A40-A41) - 3
# 8 - Cerebrovascular diseases (I60-I69) - 3
# 8 - Legal intervention (Y35,Y89.0) - 3
# 11 - Tuberculosis (A16-A19) - 2
# 11 - Chronic lower respiratory diseases (J40-J47) - 2
# 11 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 2
# 14 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 1
# 14 - Diabetes mellitus (E10-E14) - 1
# 14 - Essential hypertension and hypertensive renal disease (I10,I12,I15) - 1
# 14 - Certain conditions originating in the perinatal period (P00-P96) - 1
# 14 - Enterocolitis due to Clostridium difficile  (A04.7) - 1
# ... - All other causes (Residual)  - 57
# ====================================================
# average for category Asian or Pacific Islander, male, 25-34 years: 41.6
# median for category Asian or Pacific Islander, male, 25-34 years: 7
# ====================================================
# Asian or Pacific Islander, male, 25-34 years has 19 items
# ... - All causes  - 814
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 213
# 2 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 199
# 3 - Malignant neoplasms (C00-C97) - 98
# 4 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 74
# 5 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 47
# 6 - Chronic liver disease and cirrhosis (K70,K73-K74) - 14
# 7 - Human immunodeficiency virus (HIV) disease (B20-B24) - 12
# 8 - Cerebrovascular diseases (I60-I69) - 7
# 8 - Influenza and pneumonia (J09-J18) - 7
# 10 - Diabetes mellitus (E10-E14) - 5
# 10 - Chronic lower respiratory diseases (J40-J47) - 5
# 10 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 5
# 10 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 5
# 14 - Septicemia (A40-A41) - 4
# 14 - Viral hepatitis (B15-B19) - 4
# 14 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 4
# 14 - Aortic aneurysm and dissection (I71) - 4
# ... - All other causes (Residual)  - 107
# ====================================================
# average for category Asian or Pacific Islander, male, 35-44 years: 72.4
# median for category Asian or Pacific Islander, male, 35-44 years: 26
# average for category Asian or Pacific Islander, male, 45-54 years: 149.7
# median for category Asian or Pacific Islander, male, 45-54 years: 31
# average for category Asian or Pacific Islander, male, 5-14 years: 7.3
# median for category Asian or Pacific Islander, male, 5-14 years: 4
# average for category Asian or Pacific Islander, male, 55-64 years: 271.5
# median for category Asian or Pacific Islander, male, 55-64 years: 80
# average for category Asian or Pacific Islander, male, 65-74 years: 330.3
# median for category Asian or Pacific Islander, male, 65-74 years: 112
# average for category Asian or Pacific Islander, male, 75-84 years: 424.1
# median for category Asian or Pacific Islander, male, 75-84 years: 158
# average for category Asian or Pacific Islander, male, 85 years and over: 407.2
# median for category Asian or Pacific Islander, male, 85 years and over: 189
# average for category Asian or Pacific Islander, male, all ages: 1718.1
# median for category Asian or Pacific Islander, male, all ages: 820
# average for category Black, both sexes, 1-4 years: 51.7
# median for category Black, both sexes, 1-4 years: 20
# average for category Black, both sexes, 15-24 years: 385.6
# median for category Black, both sexes, 15-24 years: 73
# average for category Black, both sexes, 25-34 years: 530.6
# median for category Black, both sexes, 25-34 years: 150
# average for category Black, both sexes, 35-44 years: 745.7
# median for category Black, both sexes, 35-44 years: 431
# average for category Black, both sexes, 45-54 years: 1794.4
# median for category Black, both sexes, 45-54 years: 746
# average for category Black, both sexes, 5-14 years: 61.5
# median for category Black, both sexes, 5-14 years: 28
# average for category Black, both sexes, 55-64 years: 3325.7
# median for category Black, both sexes, 55-64 years: 1276
# average for category Black, both sexes, 65-74 years: 3315.3
# median for category Black, both sexes, 65-74 years: 1093
# average for category Black, both sexes, 75-84 years: 3293.7
# median for category Black, both sexes, 75-84 years: 1448
# average for category Black, both sexes, 85 years and over: 2818.3
# median for category Black, both sexes, 85 years and over: 1555
# average for category Black, both sexes, all ages: 16215.7
# median for category Black, both sexes, all ages: 8059
# average for category Black, female, 1-4 years: 19.0
# median for category Black, female, 1-4 years: 7.0
# ====================================================
# Black, female, 1-4 years has 20 items
# ... - All causes  - 445
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 122
# 2 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 66
# 3 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 41
# 4 - Malignant neoplasms (C00-C97) - 31
# 5 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 23
# 6 - Chronic lower respiratory diseases (J40-J47) - 12
# 7 - Influenza and pneumonia (J09-J18) - 10
# 8 - Septicemia (A40-A41) - 7
# 8 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 7
# 8 - Certain conditions originating in the perinatal period (P00-P96) - 7
# 11 - Anemias (D50-D64) - 4
# 12 - Cerebrovascular diseases (I60-I69) - 3
# 12 - Complications of medical and surgical care (Y40-Y84,Y88) - 3
# 14 - Meningitis (G00,G03) - 2
# 15 - Diabetes mellitus (E10-E14) - 1
# 15 - Acute bronchitis and bronchiolitis (J20-J21) - 1
# 15 - Diseases of appendix (K35-K38) - 1
# 15 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 1
# ... - All other causes (Residual)  - 103
# ====================================================
# average for category Black, female, 15-24 years: 79.6
# median for category Black, female, 15-24 years: 25
# average for category Black, female, 25-34 years: 149.6
# median for category Black, female, 25-34 years: 98
# average for category Black, female, 35-44 years: 289.2
# median for category Black, female, 35-44 years: 116
# average for category Black, female, 45-54 years: 758.0
# median for category Black, female, 45-54 years: 303
# average for category Black, female, 5-14 years: 20.6
# median for category Black, female, 5-14 years: 7.5
# ====================================================
# Black, female, 5-14 years has 20 items
# ... - All causes  - 494
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 115
# 2 - Malignant neoplasms (C00-C97) - 56
# 3 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 44
# 4 - Chronic lower respiratory diseases (J40-J47) - 32
# 4 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 32
# 6 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 22
# 7 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 20
# 8 - Influenza and pneumonia (J09-J18) - 10
# 9 - Cerebrovascular diseases (I60-I69) - 9
# 10 - Anemias (D50-D64) - 6
# 11 - Septicemia (A40-A41) - 5
# 11 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 5
# 13 - Diabetes mellitus (E10-E14) - 3
# 13 - Certain conditions originating in the perinatal period (P00-P96) - 3
# 15 - Meningitis (G00,G03) - 2
# 15 - Pneumonitis due to solids and liquids (J69) - 2
# 15 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 2
# 15 - Complications of medical and surgical care (Y40-Y84,Y88) - 2
# ... - All other causes (Residual)  - 124
# ====================================================
# average for category Black, female, 55-64 years: 1359.7
# median for category Black, female, 55-64 years: 573
# average for category Black, female, 65-74 years: 1486.1
# median for category Black, female, 65-74 years: 510
# average for category Black, female, 75-84 years: 1735.5
# median for category Black, female, 75-84 years: 822
# average for category Black, female, 85 years and over: 1881.8
# median for category Black, female, 85 years and over: 1050
# average for category Black, female, all ages: 7757.5
# median for category Black, female, all ages: 4050
# average for category Black, male, 1-4 years: 25.8
# median for category Black, male, 1-4 years: 12
# ====================================================
# Black, male, 1-4 years has 19 items
# ... - All causes  - 561
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 177
# 2 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 70
# 3 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 50
# 4 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 36
# 5 - Malignant neoplasms (C00-C97) - 33
# 6 - Chronic lower respiratory diseases (J40-J47) - 15
# 7 - Septicemia (A40-A41) - 13
# 7 - Influenza and pneumonia (J09-J18) - 13
# 9 - Cerebrovascular diseases (I60-I69) - 12
# 10 - Certain conditions originating in the perinatal period (P00-P96) - 6
# 11 - Anemias (D50-D64) - 4
# 11 - Meningitis (G00,G03) - 4
# 13 - Complications of medical and surgical care (Y40-Y84,Y88) - 2
# 14 - Acute bronchitis and bronchiolitis (J20-J21) - 1
# 14 - Pneumoconioses and chemical effects (J60-J66,J68) - 1
# 14 - Pneumonitis due to solids and liquids (J69) - 1
# 14 - Enterocolitis due to Clostridium difficile  (A04.7) - 1
# ... - All other causes (Residual)  - 122
# ====================================================
# average for category Black, male, 15-24 years: 307.1
# median for category Black, male, 15-24 years: 48
# average for category Black, male, 25-34 years: 383.9
# median for category Black, male, 25-34 years: 74
# average for category Black, male, 35-44 years: 460.7
# median for category Black, male, 35-44 years: 269
# average for category Black, male, 45-54 years: 1036.4
# median for category Black, male, 45-54 years: 456
# average for category Black, male, 5-14 years: 37.3
# median for category Black, male, 5-14 years: 18
# average for category Black, male, 55-64 years: 1968.8
# median for category Black, male, 55-64 years: 874
# average for category Black, male, 65-74 years: 1829.6
# median for category Black, male, 65-74 years: 674
# average for category Black, male, 75-84 years: 1558.2
# median for category Black, male, 75-84 years: 626
# average for category Black, male, 85 years and over: 936.5
# median for category Black, male, 85 years and over: 561
# average for category Black, male, all ages: 8473.3
# median for category Black, male, all ages: 3976
# average for category White, both sexes, 1-4 years: 137.7
# median for category White, both sexes, 1-4 years: 32
# average for category White, both sexes, 15-24 years: 1202.7
# median for category White, both sexes, 15-24 years: 113
# average for category White, both sexes, 25-34 years: 1913.9
# median for category White, both sexes, 25-34 years: 338
# average for category White, both sexes, 35-44 years: 2905.2
# median for category White, both sexes, 35-44 years: 1057
# average for category White, both sexes, 45-54 years: 7800.9
# median for category White, both sexes, 45-54 years: 3610
# average for category White, both sexes, 5-14 years: 189.4
# median for category White, both sexes, 5-14 years: 62.5
# ====================================================
# White, both sexes, 5-14 years has 18 items
# ... - All causes  - 3,841
# 1 - Accidents (unintentional injuries) (V01-X59,Y85-Y86) - 1,105
# 2 - Malignant neoplasms (C00-C97) - 717
# 3 - Intentional self-harm (suicide) (*U03,X60-X84,Y87.0) - 312
# 4 - Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99) - 242
# 5 - Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) - 170
# 6 - Diseases of heart (I00-I09,I11,I13,I20-I51) - 105
# 7 - Influenza and pneumonia (J09-J18) - 92
# 8 - Cerebrovascular diseases (I60-I69) - 66
# 9 - Chronic lower respiratory diseases (J40-J47) - 59
# 10 - In situ neoplasms, benign neoplasms and neoplasms of uncertain or unknown behavior (D00-D48) - 45
# 11 - Septicemia (A40-A41) - 38
# 12 - Certain conditions originating in the perinatal period (P00-P96) - 24
# 13 - Diabetes mellitus (E10-E14) - 20
# 14 - Complications of medical and surgical care (Y40-Y84,Y88) - 17
# 15 - Meningitis (G00,G03) - 9
# 15 - Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27) - 9
# ... - All other causes (Residual)  - 811
# ====================================================
# average for category White, both sexes, 55-64 years: 15266.7
# median for category White, both sexes, 55-64 years: 6714
# average for category White, both sexes, 65-74 years: 21686.0
# median for category White, both sexes, 65-74 years: 6329
# average for category White, both sexes, 75-84 years: 29841.1
# median for category White, both sexes, 75-84 years: 12082
# average for category White, both sexes, 85 years and over: 38078.7
# median for category White, both sexes, 85 years and over: 15023
# average for category White, both sexes, all ages: 117654.9
# median for category White, both sexes, all ages: 49013
# average for category White, female, 1-4 years: 57.1
# median for category White, female, 1-4 years: 13
# average for category White, female, 15-24 years: 320.2
# median for category White, female, 15-24 years: 65
# average for category White, female, 25-34 years: 557.2
# median for category White, female, 25-34 years: 159
# average for category White, female, 35-44 years: 1066.3
# median for category White, female, 35-44 years: 353
# average for category White, female, 45-54 years: 2949.2
# median for category White, female, 45-54 years: 1532
# average for category White, female, 5-14 years: 85.1
# median for category White, female, 5-14 years: 35
# average for category White, female, 55-64 years: 5782.5
# median for category White, female, 55-64 years: 1830
# average for category White, female, 65-74 years: 9169.1
# median for category White, female, 65-74 years: 2923
# average for category White, female, 75-84 years: 14327.3
# median for category White, female, 75-84 years: 5891
# average for category White, female, 85 years and over: 23247.5
# median for category White, female, 85 years and over: 8492
# average for category White, female, all ages: 56923.3
# median for category White, female, all ages: 26106
# average for category White, male, 1-4 years: 80.5
# median for category White, male, 1-4 years: 19
# average for category White, male, 15-24 years: 884.7
# median for category White, male, 15-24 years: 67
# average for category White, male, 25-34 years: 1363.5
# median for category White, male, 25-34 years: 196
# average for category White, male, 35-44 years: 1847.5
# median for category White, male, 35-44 years: 603
# average for category White, male, 45-54 years: 4856.8
# median for category White, male, 45-54 years: 1789
# average for category White, male, 5-14 years: 116.6
# median for category White, male, 5-14 years: 38
# average for category White, male, 55-64 years: 9498.8
# median for category White, male, 55-64 years: 4726
# average for category White, male, 65-74 years: 12520.9
# median for category White, male, 65-74 years: 3404
# average for category White, male, 75-84 years: 15513.8
# median for category White, male, 75-84 years: 6299
# average for category White, male, 85 years and over: 14833.1
# median for category White, male, 85 years and over: 6765
# average for category White, male, all ages: 60731.6
# median for category White, male, all ages: 23648
#
# Analysis complete.

# %% [markdown]
# # More analysis
# The function **getTop3CausesOfDeath()** displays the top 3 causes of death as defined by the top **Percents of total deaths**. The top 3 found were as follows:
# * 49.7% : Malignant neoplasms (C00-C97) in category Asian or Pacific Islander, female, 45-54 years
# * 49.2% : Assault (homicide) (* U01-* U02,X85-Y09,Y87.1) in category Black, male, 15-24 years
# * 48.7% : Accidents (unintentional injuries) (V01-X59,Y85-Y86) in category American Indian, female, 1-4 years
#
# The function **setRacesSexesAgesCauses()** initializes the sets **races**, **sexes**, and **ageGroups** with all the distinct values from the set of **categories**, and initializes the set **causes** from the items in **extendedDataList** where **rank** is not "...". The function **sortedAgeGroups()** returns a list of age groups that are sorted numerically, not alphabetically.
#
# The functions **trendsForRace()**, **trendsForSex()**, and **trendsForAge()** each find the trends for a given demographic using similiar but not exact logic. (In particular, **trendsForSex()** had to search for trends in the data in **extendedDataList** carefully when the sex = "male", because the characters of "male" are also in "female".)
#
# Some interesting correlations in the data include:
# * The 3rd top cause of death, "Accidents (unintentional injuries) (V01-X59,Y85-Y86)", 48.7% in American Indian, female, 1-4 years, was one of the most common for race American Indian, found 22 times, and was one of the most common for the sex female, found 44 times, and was one of the most common for age group 1-4 years, found 8 times.
# * The 2nd top cause of death, "Assault (homicide) (* U01-* U02,X85-Y09,Y87.1)", 49.2% in Black, male, 15-24 years was NOT found among the most common causes of death for race Black, and was NOT found among the sex male, but was among age group 15-24 years, found 8 times.
# * The top cause of death, as measured by Percents of total deaths, "Malignant neoplasms (C00-C97)", 49.7% in Asian or Pacific Islander, female, 45-54 years, was one of the most common for race Asian or Pacific Islander, found 22 times, and was among most common for the sex female, found 44 times, and was one of the most common for age group 45-54 years, found 8 times.

# %%
top3 = list()

def getTop3CausesOfDeath():
    """
    Just comparing the first two categories from the original data source, "AR,BS,AA" & "AR,BS,1-4",
    Diseases of heart (I00-I09,I11,I13,I20-I51) wins just by Numbers, but
    Accidents (unintentional injuries) (V01-X59,Y85-Y86) wins by Percent of total deaths.
    
    Compare the top rated Percent of total deaths across all categories, to see which are the top 3
    """
    topN = dict()
    
    for item in extendedDataList:
        if "..." not in item.rank:
            topN.update({float(item.percent):item})
    count = 0
    print("Top 3 causes of death (by Percent of total deaths):")
    for key in sorted(topN.keys(), reverse=True):
        print(str(key) + "% : " + topN.get(key).cause + " in category " + topN.get(key).category)
        count += 1
        top3.append(topN.get(key))
        if count > 2:
            break

getTop3CausesOfDeath()
print()

races = set()
sexes = set()
ageGroups = set()
causes = set()

def setRacesSexesAgesCauses():
    #Purpose: Populate the race, sex, and age sets from categories
    prevRaceLen = 0
    prevAgeLen = 0
    for cat in categories:
        subCats = cat.split(",")
        if "All races" not in subCats[0]:
            races.add(subCats[0])
        if "all ages" not in subCats[2]:
            ageGroups.add(subCats[2])
        """if len(races) > prevRaceLen:
            prevRaceLen = len(races)
            print("Added race: " + subCats[0])
        if len(ageGroups) > prevAgeLen:
            prevAgeLen = len(ageGroups)
            print("Added age group: " + subCats[2])"""
    #Note: Until the list of sexes increases from just "male", "female", and "both sexes", 
    #that collection can be initialized manually, excluding "both sexes"
    sexes.add("male")
    sexes.add("female")
    for item in extendedDataList:
        #Excluding All causes and All other...
        if "..." not in item.rank:
            causes.add(item.cause)

setRacesSexesAgesCauses()

def sortedAgeGroups():
    sortedAges = list()
    ageGroupsCopy = ageGroups.copy()
    for ageGroup in sorted(ageGroupsCopy):
        if ageGroup[2] == "-":
            sortedAges.append(ageGroup)
            ageGroupsCopy.remove(ageGroup)
    for ageGroup in sorted(ageGroupsCopy):
        sortedAges.append(ageGroup)
    return sortedAges

def trendsForRace(race):
    #Most common causes
    mostCommon = dict()
    for item in extendedDataList:
        #Excluding all ages and both sexes
        if "All" not in item.category and "both" not in item.category and race in item.category \
            and "All" not in item.cause:
            count = mostCommon.get(item.cause, 0)
            mostCommon.update({item.cause : count+1})
    count = 0
    print("The following causes of death for race " + race + " were the most common, found ", end='')
    for value in sorted(mostCommon.values(), reverse=True):
        print(str(value) + " times: ")
        for key in mostCommon.keys():
            if mostCommon.get(key) == value:
                print(key)
        break
    print()
    
    #Causes not found
    founds = set(mostCommon.keys())
    notFounds = causes.difference(founds)
    print("The following " + str(len(notFounds)) + " causes of death for race " + race + " were not found: ")
    for notFound in notFounds:
        print(notFound)
    print()

def trendsForSex(sex):
    #Most common causes
    mostCommon = dict()
    for item in extendedDataList:
        #Excluding all ages and all races
        if "All" not in item.category and "all" not in item.category and "All" not in item.cause:
            #Since the characters for "male" are in "female", have to be a little kludgey with this...
            if (sex == "female" and sex in item.category) or \
                (sex == "male" and sex in item.category and "female" not in item.category):
                count = mostCommon.get(item.cause, 0)
                mostCommon.update({item.cause : count+1})
    count = 0
    print("The following causes of death for sex " + sex + " were the most common, found ", end='')
    for value in sorted(mostCommon.values(), reverse=True):
        print(str(value) + " times: ")
        for key in mostCommon.keys():
            if mostCommon.get(key) == value:
                print(key)
        break
    print()
    
    #Causes not found
    founds = set(mostCommon.keys())
    notFounds = causes.difference(founds)
    print("The following " + str(len(notFounds)) + " causes of death for sex " + sex + " were not found: ")
    for notFound in notFounds:
        print(notFound)
    print()
    
def trendsForAge(ageGroup):
    #Most common causes
    mostCommon = dict()
    for item in extendedDataList:
        #Excluding both sexes and all races
        if "All" not in item.category and "both" not in item.category and "All" not in item.cause \
            and ageGroup in item.category:
            count = mostCommon.get(item.cause, 0)
            mostCommon.update({item.cause : count+1})
    count = 0
    print("The following causes of death for age group" + ageGroup + " were the most common, found ", end='')
    for value in sorted(mostCommon.values(), reverse=True):
        print(str(value) + " times: ")
        for key in mostCommon.keys():
            if mostCommon.get(key) == value:
                print(key)
        break
    print()
    
    #Causes not found
    founds = set(mostCommon.keys())
    notFounds = causes.difference(founds)
    print("The following " + str(len(notFounds)) + " causes of death for age group" + ageGroup + " were not found: ")
    for notFound in notFounds:
        print(notFound)
    print()

def findTrends():
    for race in sorted(races):
        trendsForRace(race)
    for sex in sorted(sexes):
        trendsForSex(sex)
    for ageGroup in sortedAgeGroups():
        trendsForAge(ageGroup)

findTrends()
# Out:
# Top 3 causes of death (by Percent of total deaths):
# 49.7% : Malignant neoplasms (C00-C97) in category Asian or Pacific Islander, female, 45-54 years
# 49.2% : Assault (homicide) (*U01-*U02,X85-Y09,Y87.1) in category Black, male, 15-24 years
# 48.7% : Accidents (unintentional injuries) (V01-X59,Y85-Y86) in category American Indian, female, 1-4 years
#
# The following causes of death for race American Indian were the most common, found 22 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Malignant neoplasms (C00-C97)
#
# The following 5 causes of death for race American Indian were not found:
# Pneumoconioses and chemical effects (J60-J66,J68)
# Anemias (D50-D64)
# Meningitis (G00,G03)
# Diseases of appendix (K35-K38)
# Shigellosis and amebiasis (A03,A06)
#
# The following causes of death for race Asian or Pacific Islander were the most common, found 22 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
#
# The following 5 causes of death for race Asian or Pacific Islander were not found:
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Diseases of appendix (K35-K38)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
#
# The following causes of death for race Black were the most common, found 22 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Chronic lower respiratory diseases (J40-J47)
# Influenza and pneumonia (J09-J18)
# Septicemia (A40-A41)
# Cerebrovascular diseases (I60-I69)
#
# The following 6 causes of death for race Black were not found:
# Hernia (K40-K46)
# Shigellosis and amebiasis (A03,A06)
# Tuberculosis (A16-A19)
# Nutritional deficiencies (E40-E64)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Infections of kidney (N10-N12,N13.6,N15.1)
#
# The following causes of death for race White were the most common, found 22 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Influenza and pneumonia (J09-J18)
# Septicemia (A40-A41)
# Chronic lower respiratory diseases (J40-J47)
# Cerebrovascular diseases (I60-I69)
#
# The following 9 causes of death for race White were not found:
# Enterocolitis due to Clostridium difficile  (A04.7)
# Hernia (K40-K46)
# Shigellosis and amebiasis (A03,A06)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Tuberculosis (A16-A19)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Infections of kidney (N10-N12,N13.6,N15.1)
#
# The following causes of death for sex female were the most common, found 40 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Influenza and pneumonia (J09-J18)
# Malignant neoplasms (C00-C97)
#
# The following 4 causes of death for sex female were not found:
# Enterocolitis due to Clostridium difficile  (A04.7)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Legal intervention (Y35,Y89.0)
# Hernia (K40-K46)
#
# The following causes of death for sex male were the most common, found 40 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
#
# The following 4 causes of death for sex male were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Shigellosis and amebiasis (A03,A06)
# Diseases of appendix (K35-K38)
#
# The following causes of death for age group 1-4 years were the most common, found 8 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
# Malignant neoplasms (C00-C97)
#
# The following 13 causes of death for age group 1-4 years were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Viral hepatitis (B15-B19)
# Atherosclerosis (I70)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Legal intervention (Y35,Y89.0)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Human immunodeficiency virus (HIV) disease (B20-B24)
# Parkinson's disease (G20-G21)
# Tuberculosis (A16-A19)
# Alzheimer's disease (G30)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
# Aortic aneurysm and dissection (I71)
#
# The following causes of death for age group 5-14 years were the most common, found 8 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
#
# The following 18 causes of death for age group 5-14 years were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Shigellosis and amebiasis (A03,A06)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Legal intervention (Y35,Y89.0)
# Alzheimer's disease (G30)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Human immunodeficiency virus (HIV) disease (B20-B24)
# Parkinson's disease (G20-G21)
# Tuberculosis (A16-A19)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Aortic aneurysm and dissection (I71)
#
# The following causes of death for age group 15-24 years were the most common, found 8 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Septicemia (A40-A41)
# Diabetes mellitus (E10-E14)
# Chronic lower respiratory diseases (J40-J47)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
#
# The following 15 causes of death for age group 15-24 years were not found:
# Viral hepatitis (B15-B19)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Hernia (K40-K46)
# Shigellosis and amebiasis (A03,A06)
# Pneumonitis due to solids and liquids (J69)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Alzheimer's disease (G30)
# Parkinson's disease (G20-G21)
# Meningitis (G00,G03)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Aortic aneurysm and dissection (I71)
#
# The following causes of death for age group 25-34 years were the most common, found 8 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Malignant neoplasms (C00-C97)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Diabetes mellitus (E10-E14)
# Septicemia (A40-A41)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Cerebrovascular diseases (I60-I69)
# Influenza and pneumonia (J09-J18)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
#
# The following 11 causes of death for age group 25-34 years were not found:
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Shigellosis and amebiasis (A03,A06)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Parkinson's disease (G20-G21)
# Meningitis (G00,G03)
# Diseases of appendix (K35-K38)
# Alzheimer's disease (G30)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Certain conditions originating in the perinatal period (P00-P96)
#
# The following causes of death for age group 35-44 years were the most common, found 8 times:
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Diabetes mellitus (E10-E14)
# Influenza and pneumonia (J09-J18)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Cerebrovascular diseases (I60-I69)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Human immunodeficiency virus (HIV) disease (B20-B24)
#
# The following 19 causes of death for age group 35-44 years were not found:
# Pneumoconioses and chemical effects (J60-J66,J68)
# Anemias (D50-D64)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Hernia (K40-K46)
# Nutritional deficiencies (E40-E64)
# Meningitis (G00,G03)
# Tuberculosis (A16-A19)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Complications of medical and surgical care (Y40-Y84,Y88)
# Shigellosis and amebiasis (A03,A06)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Certain conditions originating in the perinatal period (P00-P96)
# Pneumonitis due to solids and liquids (J69)
# Legal intervention (Y35,Y89.0)
# Parkinson's disease (G20-G21)
# Diseases of appendix (K35-K38)
# Alzheimer's disease (G30)
#
# The following causes of death for age group 45-54 years were the most common, found 8 times:
# Malignant neoplasms (C00-C97)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Diabetes mellitus (E10-E14)
# Chronic lower respiratory diseases (J40-J47)
# Septicemia (A40-A41)
# Cerebrovascular diseases (I60-I69)
# Viral hepatitis (B15-B19)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Influenza and pneumonia (J09-J18)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
#
# The following 20 causes of death for age group 45-54 years were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Anemias (D50-D64)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Hernia (K40-K46)
# Alzheimer's disease (G30)
# Meningitis (G00,G03)
# Tuberculosis (A16-A19)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Complications of medical and surgical care (Y40-Y84,Y88)
# Shigellosis and amebiasis (A03,A06)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Certain conditions originating in the perinatal period (P00-P96)
# Pneumonitis due to solids and liquids (J69)
# Legal intervention (Y35,Y89.0)
# Parkinson's disease (G20-G21)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
#
# The following causes of death for age group 55-64 years were the most common, found 8 times:
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Diabetes mellitus (E10-E14)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Chronic lower respiratory diseases (J40-J47)
# Cerebrovascular diseases (I60-I69)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Influenza and pneumonia (J09-J18)
# Septicemia (A40-A41)
# Viral hepatitis (B15-B19)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
#
# The following 17 causes of death for age group 55-64 years were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Hernia (K40-K46)
# Shigellosis and amebiasis (A03,A06)
# Complications of medical and surgical care (Y40-Y84,Y88)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Legal intervention (Y35,Y89.0)
# Anemias (D50-D64)
# Meningitis (G00,G03)
# Tuberculosis (A16-A19)
# Parkinson's disease (G20-G21)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Certain conditions originating in the perinatal period (P00-P96)
#
# The following causes of death for age group 65-74 years were the most common, found 8 times:
# Malignant neoplasms (C00-C97)
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Chronic lower respiratory diseases (J40-J47)
# Diabetes mellitus (E10-E14)
# Cerebrovascular diseases (I60-I69)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Septicemia (A40-A41)
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Influenza and pneumonia (J09-J18)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
#
# The following 18 causes of death for age group 65-74 years were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Hernia (K40-K46)
# Complications of medical and surgical care (Y40-Y84,Y88)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Legal intervention (Y35,Y89.0)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Anemias (D50-D64)
# Meningitis (G00,G03)
# Tuberculosis (A16-A19)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
# Shigellosis and amebiasis (A03,A06)
# Certain conditions originating in the perinatal period (P00-P96)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
#
# The following causes of death for age group 75-84 years were the most common, found 8 times:
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Malignant neoplasms (C00-C97)
# Chronic lower respiratory diseases (J40-J47)
# Diabetes mellitus (E10-E14)
# Cerebrovascular diseases (I60-I69)
# Alzheimer's disease (G30)
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Influenza and pneumonia (J09-J18)
# Septicemia (A40-A41)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Parkinson's disease (G20-G21)
#
# The following 21 causes of death for age group 75-84 years were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Anemias (D50-D64)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Atherosclerosis (I70)
# Hernia (K40-K46)
# Meningitis (G00,G03)
# Tuberculosis (A16-A19)
# Cholelithiasis and other disorders of gallbladder (K80-K82)
# Complications of medical and surgical care (Y40-Y84,Y88)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
# Shigellosis and amebiasis (A03,A06)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Certain conditions originating in the perinatal period (P00-P96)
# Legal intervention (Y35,Y89.0)
# Human immunodeficiency virus (HIV) disease (B20-B24)
# Diseases of appendix (K35-K38)
# Nutritional deficiencies (E40-E64)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)
#
# The following causes of death for age group 85 years and over were the most common, found 8 times:
# Diseases of heart (I00-I09,I11,I13,I20-I51)
# Malignant neoplasms (C00-C97)
# Cerebrovascular diseases (I60-I69)
# Alzheimer's disease (G30)
# Diabetes mellitus (E10-E14)
# Chronic lower respiratory diseases (J40-J47)
# Influenza and pneumonia (J09-J18)
# Accidents (unintentional injuries) (V01-X59,Y85-Y86)
# Essential hypertension and hypertensive renal disease (I10,I12,I15)
# Septicemia (A40-A41)
# Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)
# Parkinson's disease (G20-G21)
# Pneumonitis due to solids and liquids (J69)
#
# The following 20 causes of death for age group 85 years and over were not found:
# Pregnancy, childbirth and the puerperium (O00-O99)
# Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)
# Pneumoconioses and chemical effects (J60-J66,J68)
# Chronic liver disease and cirrhosis (K70,K73-K74)
# Anemias (D50-D64)
# Viral hepatitis (B15-B19)
# Enterocolitis due to Clostridium difficile  (A04.7)
# Acute bronchitis and bronchiolitis (J20-J21)
# Hernia (K40-K46)
# Meningitis (G00,G03)
# Tuberculosis (A16-A19)
# Complications of medical and surgical care (Y40-Y84,Y88)
# Congenital malformations, deformations and chromosomal abnormalities (Q00-Q99)
# Shigellosis and amebiasis (A03,A06)
# Infections of kidney (N10-N12,N13.6,N15.1)
# Certain conditions originating in the perinatal period (P00-P96)
# Legal intervention (Y35,Y89.0)
# Human immunodeficiency virus (HIV) disease (B20-B24)
# Diseases of appendix (K35-K38)
# Assault (homicide) (*U01-*U02,X85-Y09,Y87.1)

# %% [markdown]
# # Visualizations
# The function **chartTop3()** displays pie charts of the top 3 causes of death (as measured by **Percent of total deaths**) found in the previous step. Note that the causes of death for smaller pie pieces tend to overlap. Still, the biggest cause of death in each of these  categories is clearly the most significant factor to be aware of in each of these categories.

# %%
import matplotlib.pyplot as plt
#If import no good, follow the above pattern for tika; but should be good- matplotlib is pretty common.

#allow plots to appear within the notebook:
# %matplotlib inline

def chartTop3():
    for top in top3:
        topCategory = top.category
        categoryPercents = list()
        categoryCauses = list()
        print(topCategory)
        for item in extendedDataList:
            if item.category == topCategory:
                if allCauses not in item.cause : 
                    categoryPercents.append(item.percent)
                    categoryCauses.append(item.cause)
        plt.pie(categoryPercents, labels=categoryCauses)
        plt.show()
        print()

chartTop3()
# Out:
# Asian or Pacific Islander, female, 45-54 years
# Black, male, 15-24 years
# American Indian, female, 1-4 years
